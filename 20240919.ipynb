# %%
import pandas as pd

# %%
df = pd.read_csv('final_dataset/코스피.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6546 entries, 0 to 6545
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Symbol             6546 non-null   object
#  1   Name               6546 non-null   object
#  2   회계년                6546 non-null   int64
#  3   매출총이익률(%)          6546 non-null   float64
#  4   영업이익률(%)           6546 non-null   float64
#  5   당기순이익률(%)          6546 non-null   float64
#  6   자본금영업이익률(%)        6546 non-null   float64
#  7   영업수익/영업비용(%)       6546 non-null   float64
#  8   세전계속사업이익률(%)       6546 non-null   float64
#  9   자본금세전계속사업이익률(%)    6546 non-null   float64
#  10  자본금지배주주순이익률(%)     6546 non-null   float64
#  11  매출액증가율(전년동기)(%)    6546 non-null   float64
#  12  영업이익증가율(전년동기)(%)   6546 non-null   float64
#  13  당기순이익증가율(전년동기)(%)  6546 non-null   float64
#  14  총자본증가율(전년동기)(%)    6546 non-null   float64
# ...

# %%
df.describe()
# Out:
#                회계년    매출총이익률(%)      영업이익률(%)     당기순이익률(%)   자본금영업이익률(%)  \
# count  6546.000000  6546.000000   6546.000000   6546.000000   6546.000000
# mean   2017.178888    21.522731     -1.421850     41.467475    181.442003
# std       3.161348    22.113795    272.192819   1270.981716    609.725925
# min    2012.000000  -205.560000 -21800.490000 -12629.890000  -1797.390000
# 25%    2014.000000     9.150000      0.772500     -0.127500      5.925000
# 50%    2017.000000    14.955000      3.770000      2.830000     50.205000
# 75%    2020.000000    26.187500      7.440000      6.680000    159.320000
# max    2022.000000   100.000000     80.020000  63267.750000  13671.150000
#
#        영업수익/영업비용(%)  세전계속사업이익률(%)  자본금세전계속사업이익률(%)  자본금지배주주순이익률(%)  \
# count   6546.000000   6546.000000      6546.000000     6546.000000
# mean     104.901986     -3.943113       195.366444      160.555823
# std       17.101886    331.781096       971.855452      884.290878
# ...

# %%
a = pd.read_csv('final_dataset/코스피이상치99%처리.csv')
a['manipulate'].value_counts()
# Out:
# manipulate
# 0.0    6413
# 1.0     133
# Name: count, dtype: int64

# %%
label = pd.read_csv('final_dataset/종합.csv')
label['구분'].value_counts()
# Out:
# 구분
# 코스닥     346
# 유가증권    205
# Name: count, dtype: int64
